# %%
stname = "유니코"; stage=20; stavg=95.869 
# 모두 결과 동일
print(stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다")
print(stname, "학생은 나이가 ", stage, "이고 평균은 ", stavg, "입니다", sep="")
print("%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg))
print("{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg))
print(f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다")
# Out:
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다

# %%
v1 = stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다"
v2 = "%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg)
v3 = "{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg)
v4 = f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다"
print(v1)
print(v2)
print(v3)
print(v4)
# Out:
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다

# %%
import sys
print(sys.version)
# Out:
# 3.8.8 (default, Feb 24 2021, 15:54:32) [MSC v.1928 64 bit (AMD64)]

# %%
import os
print(os.getcwd())
# Out:
# c:\jsj\PYDATAexam

# %%
# !jupyter kernelspec list # 현재 인식되고 있는 커널이 무엇이 있는가
# Out:
# Available kernels:
#   pydatavenv    C:\Users\jinsujeong\AppData\Roaming\jupyter\kernels\pydatavenv
#   python3       C:\Users\jinsujeong\anaconda3\share\jupyter\kernels\python3

# %%
# !dir # 현재 워킹 디렉토리의 파일 리스트를 보여줌
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 2AD6-42E1
#
#  c:\jsj\PYDATAexam 디렉터리
#
# 2021-03-24  오후 04:34    <DIR>          .
# 2021-03-24  오후 04:34    <DIR>          ..
# 2021-03-24  오후 04:20    <DIR>          .ipynb_checkpoints
# 2021-03-24  오후 12:59            54,401 exam0.ipynb
# 2021-03-24  오후 04:34            26,883 exam1.ipynb
# 2021-03-24  오후 03:26               850 first.ipynb
# 2021-03-24  오후 03:45               856 second.ipynb
#                4개 파일              82,990 바이트
#                3개 디렉터리  86,996,357,120 바이트 남음

# %%
# 데이터 수집과 관련된 소스 코드
import urllib.request
res = urllib.request.urlopen("http://www.naver.com/")
print(type(res))
print(res.status)  # 성공했다는 뜻으로 200 출력
print(res.version) # http 프로토콜 버전 의미
print(res.msg) # 성공해서 ok
res_header = res.getheaders()  # 응답 헤더의 내용을 추출하는 메서드
print("[ header 정보 ]----------")
for s in res_header :  
    print(s)
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# 11
# OK
# [ header 정보 ]----------
# ('Server', 'NWS')
# ('Date', 'Wed, 24 Mar 2021 08:25:06 GMT')
# ('Content-Type', 'text/html; charset=UTF-8')
# ('Transfer-Encoding', 'chunked')
# ('Connection', 'close')
# ('Set-Cookie', 'PM_CK_loc=bab2e5e28de04d6f8b9581c819192a55f59dc5e1112c577776c004607c847fb1; Expires=Thu, 25 Mar 2021 08:25:06 GMT; Path=/; HttpOnly')
# ('Cache-Control', 'no-cache, no-store, must-revalidate')
# ('Pragma', 'no-cache')
# ('P3P', 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"')
# ('X-Frame-Options', 'DENY')
# ('X-XSS-Protection', '1; mode=block')
# ('Strict-Transport-Security', 'max-age=63072000; includeSubdomains')
# ('Referrer-Policy', 'unsafe-url')

# %%
import urllib.request   # URL 문자열을 가지고 HTTP 요청 수행
res = urllib.request.urlopen("http://unico2013.dothome.co.kr/crawling/tagstyle.html")
print(res) # 이런 위치에 만들어졌구나 확인
print("[ header 정보 ]----------")
res_header = res.getheaders()  # 헤더 정보 가져옴
for s in res_header :
    print(s)
print("[ body 내용 ]-----------")
#print(res.read()) # 한글은 16진수 코드 값으로 표현된다. 바이트 문자열.
#print(type(res.read())) # 바이트 객체
print(res.read().decode('utf-8')) # read 메서드를 실행하면 웹서버가 전달한 데이터(응답 바디)를 바이트 열로 읽어들임.
# 한글로 들어 있는 경우는 반드시!! decode!!
# Out:
# <http.client.HTTPResponse object at 0x0000025ADC984BE0>
# [ header 정보 ]----------
# ('Date', 'Wed, 24 Mar 2021 08:30:08 GMT')
# ('Server', 'Apache/2.2.15 (CentOS)')
# ('Content-Length', '461')
# ('Connection', 'close')
# ('Content-Type', 'text/html')
# [ body 내용 ]-----------
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>Insert title here</title>
# </head>
# <body>
# <h1>블럭스타일 태그</h1>
# <div style="background-color:yellow">테스트입니다1</div>
# <div>테스트입니다2</div>
# <div>테스트입니다3</div>
# <hr>
# <h1>인라인스타일 태그</h1>
# <span style="background-color:yellow">테스트입니다1</span>
# <span>테스트입니다2</span>
# <span>테스트입니다3</span>
# </body>
# </html>

# %%
import urllib.request
print("===========================================================")
url = 'https://www.python.org/'  # 파이썬 홈페이지
f = urllib.request.urlopen(url)
print(type(f))
print(type(f.info()))
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding) # 앞에서부터 500바이트 만큼만 읽겠다.
print(text)
print("===========================================================")

url = 'https://www.daum.net/'   
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)  # 500바이트 만큼만 읽겠다.
print(text)
print("===========================================================")

url = 'https://www.aladin.co.kr/home/welcome.aspx'   # 알라딘 홈페이지
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)

text = f.read(500).decode(encoding)
print(text)
print("===========================================================")
# Out:
# ===========================================================
# <class 'http.client.HTTPResponse'>
# <class 'http.client.HTTPMessage'>
# https://www.python.org/  페이지의 인코딩 정보 : utf-8
# <!doctype html>
# <!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->
# <!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->
# <!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->
# <!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jqu
# ===========================================================
# https://www.daum.net/  페이지의 인코딩 정보 : utf-8
# <!DOCTYPE html>
# <html lang="ko" class="">
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta property="og:url" content="https://www.daum.net/">
# <meta property="og:type" content="website">
# <meta property="og:title" content="Daum">
# <meta property="og:image" content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001">
# <meta property="og:description" content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum">
# <meta name="msapplication-task" content="name=Daum;action-
# ===========================================================
# https://www.aladin.co.kr/home/welcome.aspx  페이지의 인코딩 정보 : utf-8
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" >
# <html>
#   <head>
#       <title id="Title">알라딘</title>
#       <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>
# 	  <meta content="Microsoft Visual Studio .NET 7.1" name="GENERATOR">
# 	  <meta content="C#" name="CODE_LANGUAGE">
# 	  <meta content="JavaScript" name="vs_defaultClientScript">
# 	  <meta content="http://schemas.microsoft.com/intellisense/ie5" name="vs_targetSchema">
#       <meta http-equiv="
# ===========================================================

# %%
# 프로토콜명://서버주소(서버도메인명):포트번호/.........................
# http(https)://www.myhome.co.kr:8000/....
# 표준 포트번호 : 80임.. 80일때는 포트 번호를 생략하기도 한다.
from urllib.parse import urlparse
from urllib.parse import urlencode
print("[ URL 문자열 정보 추출 1 ]")
url1 = urlparse('https://movie.daum.net/moviedb/main?movieId=93252')
print("타입정보 : ",type(url1))
print("도메인정보 : ",url1.netloc) 
print("패스정보 : ",url1.path)
print("쿼리정보 : ",url1.query) 
print("스킴정보 : ",url1.scheme)
print("포트정보 : ",url1.port)
print("프래그먼트정보 : ",url1.fragment)
print("URL 문자열정보 : ",url1.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url1)
print("\n[ URL 문자열 정보 추출 2 ]")
url2 = urlparse('https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object')
print("도메인정보 : ",url2.netloc) 
print("패스정보 : ", url2.path)  
print("쿼리정보 : ",url2.query)
print("스킴정보 : ",url2.scheme)
print("포트정보 : ",url2.port)
print("프래그먼트정보 : ",url2.fragment)
print("URL 문자열정보 : ",url2.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url2)

print("\n[ Query문자열 또는 요청 파라미터 인코딩 ]")
params1 = urlencode({'number': 12524, 'type': 'issue', 'action': 'show'})
print(params1)
params2 = urlencode({'addr': '서울시 강남구 역삼동'})
print(params2)
# Out:
# [ URL 문자열 정보 추출 1 ]
# 타입정보 :  <class 'urllib.parse.ParseResult'>
# 도메인정보 :  movie.daum.net
# 패스정보 :  /moviedb/main
# 쿼리정보 :  movieId=93252
# 스킴정보 :  https
# 포트정보 :  None
# 프래그먼트정보 :
# URL 문자열정보 :  https://movie.daum.net/moviedb/main?movieId=93252
# urllib.parse.ParseResult 객체정보 :  ParseResult(scheme='https', netloc='movie.daum.net', path='/moviedb/main', params='', query='movieId=93252', fragment='')
#
# [ URL 문자열 정보 추출 2 ]
# 도메인정보 :  docs.python.org
# 패스정보 :  /3/library/urllib.parse.html
# 쿼리정보 :
# 스킴정보 :  https
# 포트정보 :  None
# 프래그먼트정보 :  urlparse-result-object
# URL 문자열정보 :  https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object
# urllib.parse.ParseResult 객체정보 :  ParseResult(scheme='https', netloc='docs.python.org', path='/3/library/urllib.parse.html', params='', query='', fragment='urlparse-result-object')
#
# [ Query문자열 또는 요청 파라미터 인코딩 ]
# number=12524&type=issue&action=show
# addr=%EC%84%9C%EC%9A%B8%EC%8B%9C+%EA%B0%95%EB%82%A8%EA%B5%AC+%EC%97%AD%EC%82%BC%EB%8F%99

# %%
import urllib.request
import urllib.parse
params = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % params)
url = "http://unico2013.dothome.co.kr/crawling/get.php?%s" % params
with urllib.request.urlopen(url) as f: # f라는 변수에 담음.
    print(f.read().decode('utf-8')) # 문자열로 변환한것을 화면에 내보내겠다.
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
# post 방식 1
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % data)
postdata = data.encode('ascii')
print("변환된 바이트 문자열 : %s" % postdata)
url = "http://unico2013.dothome.co.kr/crawling/post.php"
with urllib.request.urlopen(url, postdata) as f:  # 두번째 아규먼트로 전달
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# 변환된 바이트 문자열 : b'name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10'
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
# post 방식 2
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
postdata = data.encode('ascii')
req = urllib.request.Request(url='http://unico2013.dothome.co.kr/crawling/post.php',
            data=postdata)
print(req)
with urllib.request.urlopen(req) as f:
    print(f.read().decode('utf-8'))
# Out:
# <urllib.request.Request object at 0x000002BD256942B0>
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %% [markdown]
# [Http Restponse]
# Header : 응답상태 코드, 응답 메세지
#         name : value로 구성되는 정보들
#         ...
# Body : HTML 전체 내용
#     <html>
#         <head>
#             ...
#         </head>
#     <html>

# %%
import requests

r = requests.request('get', 'http://unico2013.dothome.co.kr/crawling/exam.html') # 헤드와 바디 모두 추출
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('head', 'http://unico2013.dothome.co.kr/crawling/exam.html') # 바디가 아닌 head 부분 요청
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
# html 파일은 post 방식을 지원하지 않음. 그래서 php파일로 함.
r = requests.request('post', 'http://unico2013.dothome.co.kr/crawling/post.php', data= {'name':'백도', 'age' : 12})
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# 응답된 콘텐츠가 없어요
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 백도이고 나이는 12이네요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

r = requests.head('http://unico2013.dothome.co.kr/crawling/exam.html')
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

dicdata = {'key1': 'value1', 'key2': 'value2'}
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
dicdata = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.request('GET', urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
tupledata = [('key1', 'value1'), ('key1', 'value2')]
r = requests.get(urlstr, params=tupledata)
print(r.url)
# Out:
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2&key2=value3
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key1=value2

# %%
import requests

urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
print(r.text)  # 응답된 헤더, 바디 내용을 내보냄, 인코딩 설정을 안해서 깨져서 나옴
print('------------------------------------')
r.encoding = 'utf-8'
print(r.text) # 영문 한글 모두 잘 추출 , 
print('------------------------------------')
print(r.content) # 바이트 객체로 추출해줌.  decode('utf-8') 설정 안하면 한글은 깨짐
print('------------------------------------')
print(r.content.decode('utf-8')) # 바이트 객체로 추출. 한글도 잘 나온 것 확인.
# Out:
# ï»¿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : ì´ë¦ê³¼ ëì´ë¥¼ ì ë¬í´ ì£¼ì¸ì!!</h1>   </body>
# </html>
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ------------------------------------
# b'\xef\xbb\xbf<!DOCTYPE html>\r\n<html>\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <title>POST TEST</title>\r\n  </head>\r\n  <body>\r\n   <h1>GET : \xec\x9d\xb4\xeb\xa6\x84\xea\xb3\xbc \xeb\x82\x98\xec\x9d\xb4\xeb\xa5\xbc \xec\xa0\x84\xeb\x8b\xac\xed\x95\xb4 \xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94!!</h1>   </body>\r\n</html>'
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>

# %%
import requests
from PIL import Image
from io import BytesIO

r = requests.get('http://unico2013.dothome.co.kr/image/flower.jpg')
i = Image.open(BytesIO(r.content)) # 이미지 객체를 생성한 다음에
print(type(i))
i.save("c:/Temp/test.jpg") # 이미지를 저장
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <title>Test BeautifulSoup</title>
    </head>
    <body>
        <h1>테스트</h1>
    </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')  # HTML 문서를 파싱하고 bs4.BeautifulSoup 객체 생성
print(type(bs))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')   # HTML 문서를 파싱하고 bs4.BeautifulSoup 객체 생성
print(bs.prettify())
print(bs)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Test BeautifulSoup
#   </title>
#  </head>
#  <body>
#   <p align="center">
#    P태그의 컨텐트
#   </p>
#   <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300"/>
#  </body>
# </html>
#
#
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>Test BeautifulSoup</title>
# </head>
# <body>
# <p align="center">P태그의 컨텐트</p>
# <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300"/>
# </body>
# </html>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.title), ':', bs.title)
print(type(bs.title.name), ':', bs.title.name)
print(type(bs.title.string), ':', bs.title.string)
print('-------------------------')
print(type(bs.p['align']), ':', bs.p['align'])
print(type(bs.img['src']), ':', bs.img['src'])
print(type(bs.img.attrs), ':', bs.img.attrs)  # 속성 추출
# Out:
# <class 'bs4.element.Tag'> : <title>Test BeautifulSoup</title>
# <class 'str'> : title
# <class 'bs4.element.NavigableString'> : Test BeautifulSoup
# -------------------------
# <class 'str'> : center
# <class 'str'> : http://unico2013.dothome.co.kr/image/flower.jpg
# <class 'dict'> : {'src': 'http://unico2013.dothome.co.kr/image/flower.jpg', 'width': '300'}

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print("[ string 속성 ]")
print(type(bs.p.string), ':', bs.p.string)
print(type(bs.ul.string), ':', bs.ul.string)
print(type(bs.ul.li.string), ':', bs.ul.li.string)
print(type(bs.ul.li.strong.string), ':', bs.ul.li.strong.string)
print("[ text 속성 ]")
print(type(bs.p.text), ':', bs.p.text)
print(type(bs.ul.text), ':', bs.ul.text)
print(type(bs.ul.li.text), ':', bs.ul.li.text)
print(type(bs.ul.li.strong.text), ':', bs.ul.li.strong.text)
print("[ contents 속성 ]")
print(type(bs.p.contents), ':', bs.p.contents) # contents : 태그든 text든 다 꺼내서 리스트로 보여줌.
print(type(bs.ul.contents), ':', bs.ul.contents)
print(type(bs.ul.li.contents), ':', bs.ul.li.contents)
print(type(bs.ul.li.strong.contents), ':', bs.ul.li.strong.contents)
# Out:
# [ string 속성 ]
# <class 'bs4.element.NavigableString'> : P태그의 컨텐트
# <class 'NoneType'> : None
# <class 'NoneType'> : None
# <class 'bs4.element.NavigableString'> : 강조
# [ text 속성 ]
# <class 'str'> : P태그의 컨텐트
# <class 'str'> :
# 테스트1강조
# 테스트2
# 테스트3
#
# <class 'str'> : 테스트1강조
# <class 'str'> : 강조
# [ contents 속성 ]
# <class 'list'> : ['P태그의 컨텐트']
# <class 'list'> : ['\n', <li>테스트1<strong>강조</strong></li>, '\n', <li>테스트2</li>, '\n', <li>테스트3</li>, '\n']
# <class 'list'> : ['테스트1', <strong>강조</strong>]
# <class 'list'> : ['강조']

# %%
html_doc="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right">  text contents 2 </p>
     <p align="left">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
     <div>
       <p>text contents 4</p> 
     </div>
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.find('p')))
print(type(bs.find_all('p')))
print("---------------------------------")
print(bs.find('title'))
print(bs.find('p'))
print(bs.find('img'))
print("---------------------------------")
ptags = bs.find_all('p')
print(ptags)
print("----------------")
for tag in ptags :
    print(tag)
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.ResultSet'>
# ---------------------------------
# <title>Test BeautifulSoup</title>
# <p align="center"> text contents </p>
# <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500"/>
# ---------------------------------
# [<p align="center"> text contents </p>, <p align="right">  text contents 2 </p>, <p align="left">   text contents 3 </p>, <p>text contents 4</p>]
# ----------------
# <p align="center"> text contents </p>
# <p align="right">  text contents 2 </p>
# <p align="left">   text contents 3 </p>
# <p>text contents 4</p>

# %%
html="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right" class="myp">  text contents 2 </p>
     <p align="left" a="b">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('p', align="center"))
print(bs.find('p', class_="myp"))
print(bs.find('p', align="left"))
print("-------------------------------------")
print(bs.find('p', attrs={"align":"center"}))
print(bs.find('p', attrs={"align":"right", "class":"myp"}))
print(bs.find('p', attrs={"align":"left"}))

pdom = bs.find('p', align="left")
print("["+pdom.text+"]")
print("["+pdom.get_text(strip=True)+"]")
print("["+pdom.string.strip()+"]")
# Out:
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# -------------------------------------
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# [   text contents 3 ]
# [text contents 3]
# [text contents 3]

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
html = req.content
print(type(html))
html = html.decode('utf-8')
#print(html)
print("==============================")
bs = BeautifulSoup(html, 'html.parser')
title = bs.select('h1')
title1 = bs.select('#f_subtitle')
title2 = bs.select('.subtitle')
title3 = bs.select('aside > h2')
img = bs.select('[src]')
print(title)
print(type(title))
print(type(title[0]))
print("<h1>태그의 갯수 : %d " %len(title))
print("f_subtitle이라는 id 속성을 갖는 태그 갯수 : %d " %len(title1))
print("subtitle이라는 class 속성을 갖는 태그 갯수 : %d " %len(title2))
print("aside 태그의 <h2> 자식 태그 갯수 : %d " %len(title3))
print("src 속성을 갖는 태그 갯수 : %d " %len(img))

for content in title:
    print(content.string)
print("------------------------------")
for content in title1:
    print(content.text)
print("------------------------------")
for content in title2:
    print(content.text)
print("------------------------------")
for content in title3:
    print(content.text)
print("------------------------------")
for content in img:
   print(content["src"])
# Out:
# <class 'bytes'>
# ==============================
# [<h1>CSS 선택자 학습</h1>]
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.Tag'>
# <h1>태그의 갯수 : 1
# f_subtitle이라는 id 속성을 갖는 태그 갯수 : 1
# subtitle이라는 class 속성을 갖는 태그 갯수 : 2
# aside 태그의 <h2> 자식 태그 갯수 : 1
# src 속성을 갖는 태그 갯수 : 1
# CSS 선택자 학습
# ------------------------------
# 교육과정 소개
# ------------------------------
# 웹 클라이언트 기술
# 학습 순서(수집)
# ------------------------------
# 학습 순서(수집)
# ------------------------------
# https://www.python.org/static/img/python-logo.png

# %%
import requests
from bs4 import BeautifulSoup
import re
req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page=1') # 웹페이지가 utf-8이 아니라면 인코딩 설정을 따로 하지 않고 꺼내도 됨.
html = req.text
soup = BeautifulSoup(html, 'html.parser')
titles = soup.select('.movie')
points = soup.select('td.title > div > em')
reviews = soup.select('td.title')
movie_title = []
movie_point = []
movie_review = [] 

for dom in titles:
    movie_title.append(dom.text)
for dom in points:
    movie_point.append(dom.text)
for dom in reviews:
    content = dom.contents[6]  # 모든 자식들에 대하여 리스트로 리턴 . 그중에서 7번째를 가져옴.
    #content=re.sub("신고", '', content)
    content=re.sub("[\n\t]", '', content)    # re.sub는 개행문자, 탭문자는 제거 시킴.
    movie_review.append(content)
commentLength = len(movie_title)   
for i in range(commentLength):
    print("영화 제목 : " + movie_title[i])
    print("평점 : " + movie_point[i])
    print("리뷰글 : " + movie_review[i])
    print("-----------------------------------------")
# Out:
# 영화 제목 : 고질라 VS. 콩
# 평점 : 10
# 리뷰글 : 이런 영화를 볼수 있는 시대에 살고 있다는것이 축복이라고 느낄정도로 최고.
# -----------------------------------------
# 영화 제목 : 대통령의 7시간
# 평점 : 1
# 리뷰글 : 가짜뉴스 생산하는 고발뉴스 이상호기자 ㅉㅉ
# -----------------------------------------
# 영화 제목 : 프로젝트 파워
# 평점 : 8
# 리뷰글 : 오 뭐야 꽤 괜찮은데.. 재미있게 봤음
# -----------------------------------------
# 영화 제목 : 특종: 량첸살인기
# 평점 : 8
# 리뷰글 : 초반에 젊은 여자랑 남자 살인할때부터 살인자배우를 실루엣보구 어떤배우인지 맞춰버렸다 ㅋ
# -----------------------------------------
# 영화 제목 : 인천스텔라
# 평점 : 9
# 리뷰글 : 간만에 빵빵터지면서 본 영화ㅎㅎ 백승기 유니버스 끝장판
# -----------------------------------------
# 영화 제목 : 고질라 VS. 콩
# 평점 : 10
# 리뷰글 : 고질라 대 콩 진짜 기대 이상으로 재밌게 보고 나왔습니다.
# -----------------------------------------
# 영화 제목 : 고질라 VS. 콩
# 평점 : 10
# 리뷰글 : 올바른 괴수영화. 다때려부수자.
# -----------------------------------------
# 영화 제목 : 고질라 VS. 콩
# 평점 : 10
# 리뷰글 : 소녀와 교감하는 콩이라니!! 뭔가 특별하면서도 친숙하게 다가오네요ㅎㅎㅎ
# -----------------------------------------
# 영화 제목 : 천군
# 평점 : 1
# 리뷰글 : 퉤  퉷  퉸  튓  투ㅔㅅ 투ㅔ  투 ㅣㅅ
# -----------------------------------------
# 영화 제목 : 잭 스나이더의 저스티스 리그
# 평점 : 10
# 리뷰글 : 저스티스리그는 이렇게 개봉을 했었어야됨
# -----------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import re
for n in range(1,31): # 30페이지라서 
    req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page='+str(n))
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.select('.movie' )
    points = soup.select('td.title > div > em')
    reviews = soup.select('td.title')
    movie_title = []
    movie_point = []
    movie_review = [] 
    for dom in titles:
        movie_title.append(dom.text)
    for dom in points:
        movie_point.append(dom.text)
    for dom in reviews:
        content = dom.contents[6]
        #content=re.sub("신고", '', content)
        content=re.sub("[\n\t]", '', content)
        movie_review.append(content)

    commentLength = len(movie_title)   
    for i in range(commentLength):
        print(movie_point[i] + ","+movie_title[i]+","+movie_review[i])
    print("-----------------------------------------------------")
# Out:
# 10,고질라 VS. 콩,전투씬이 않끊기고 쭉 이어져서 기분이 딲좋앜ㅅ습니다
# 2,천군,중공에서온 간첩 끄지쁘라 천안문으로 뛩크타고
# 10,미나리,뛰어난 영상에 스며든 음악의 조화!! 이모든 절경에 자연스럽게 빠져들게 만든 배우들의 연기력~ 잔잔하지만 벅찼다 조용하고 뜨거운 기립박수!!
# 2,최면,자꾸 개나소나 감독하고 그러지. 연출, 각본 다 거지같은데 그걸 한사람이 다했네 ㄷㄷ
# 10,콩: 스컬 아일랜드,이게 청소년기 일줄이야
# 10,고질라 VS. 콩,우리가 보고싶었던거 다보여줌  ^___^
# 10,고질라,영화관에서 못본게 아쉽다
# 9,태극기 휘날리며,안타까운 역사.. 그리고 안타까운 이은주..
# 10,고질라: 킹 오브 몬스터,스토리는 엠마만 빼면 평타였던것 같다.제대로 된 괴수물을 본 게 정말 오랜만이라기분이 좋다
# 10,중경삼림,홍콩여행 가기 전에 꼭 봐야하는 영화입니다... 진짜 친구들한테 추천 오지게 하는 영화입니다. 이 영화보고 홍콩 새벽 길거리 이어폰 끼고 ost 들으면서 그 갬성 잊지 못합니다. 중경삼림에서 유명한 에스컬레이터 관광 가셔서 듣고 있어도 영화 생각나면서 좋습니다
# -----------------------------------------------------
# 10,잭 스나이더의 저스티스 리그,이걸 어떻게 그렇게 망쳤지...?
# 10,잭 스나이더의 저스티스 리그,확실히 잘만든 영화이지만 4시간짜리이기 때문에 중간에 잠깐 지루할수있다 플래쉬 중요하게 나와서 좋았다 슈퍼맨이 플래쉬랑 속도 비비는게 플래쉬가 봐준거라는게 너무 좋았음 전작에선 그냥 개털리던데 여기선 이유가 있었다는게 납득이 갔다맨오브스틸도 진짜 잘만들었다고 생각했고 배대슈는 좀 실망했었는데 저스티스리그는 재밌게 잘만들었다 생각한다난 배트맨 팬인데 배트맨 너무 약해ㅠㅠ배대슈애서 배트맨은 범죄자를 죽이지 않는다 이거만 좀 지켜줬으면 난 좋게 봤을거야
# 10,고질라 VS. 콩,돈을 정말 많이 쓴 영화.Cg를 아낌없이 러닝타임 전체에 꽉꽉 채워 넣었다.덕분에 퀄리티 높은 전투가 상당히 많다.재미있다. 굿근데 러셀 가문은 DNA에 영화를 망치자는 악의가 각인되어 있는지 전작의 앰마도, 이번 작의 메디슨도 다 끔찍하다. 메카고지라가 이것들을 죽였어야 했는데...
# 10,애프터: 그 후,
# 10,잭 스나이더의 저스티스 리그,
# 10,인천스텔라,...이건 애매한데 10점줄꼐요 호불호갈리듯
# 10,고질라 VS. 콩,영화관에서 봐라. 집구석에서 볼생각하지말고.
# 10,고질라 VS. 콩,그냥재밌긴한데 이거 영화관에서 보긴하는데...뭐지 이돈 아까운 느낌은
# 10,스파이의 아내,사랑인가, 배신인가, 배신의 옷을 입은 사랑인가, 사랑의 옷을 입은 배신인가, 단순한듯 전혀 단순하지 않은 굉장한 영화를 봤다
# 10,인천스텔라,와우 대박ㄷㄷㄷ
# -----------------------------------------------------
# 10,고질라 VS. 콩,괴수 영화 좋아한다면 꼭 봐야될영화1편 2편보다 재미있음
# 8,잭 스나이더의 저스티스 리그,지난 것에 대한 확실한 보상.드디어 캐릭터 간 개연성과 역할 확보.(팬심으로 별점은 조금 더...ㅋㅋ)너무 늘어지고 불필요한 장면들은 감점요인.
# 9,고질라 VS. 콩,미안하다 이거 보여 주려고 인간 어그로 끌었다, 고질라 콩 싸움 수준 ㄹㅇ 실화냐? 진짜 세계관 최강자들의 싸움이다...
# 10,더 박스,음악에 집중한 진짜 음악영화!너무 신선하다 극장에서 빵빵한 사운드로 들으니 더 좋은것 같다 음악소리와 함께 심장이 쿵쿵된다 특히 드럼씬은 전율이 느껴질 정도! 싱어롱하면 너무 좋을 것 같다
# 10,고질라 VS. 콩,문재인 한테 받은 스트레스 다풀고 왔습니다   진짜 재밌네요
# 8,고질라 VS. 콩,중국자본이 들어가서 좀 아쉽지만 나름대로 괜찮은듯
# 1,천군,조선족 짱깨새끼들 10점준거봐 역겹다.
# 5,윤희에게,<러브레터>와 김희애 사모님은 간격이 크지..
# 1,최면,30분 보다 꿀자 잤어요 감사합니다
# 6,날씨의 아이,아이들이 보기엔 이해하기 힘든, 어른들이 보기엔 조금 유치한 그런 애매한 영화.
# -----------------------------------------------------
# 10,고질라 VS. 콩,알파급 두마리의 격투!! 믓지다아!!!
# 10,극장판 귀멸의 칼날: 무한열차편,재미있어요 전체 만화를 보지 않고 에니메이션 1기를 보고 재미있겠다 싶어서 보는 사람이라면 렌코쿠가 왜 아버지와 어머니 회상을 하는지 등등의 내용을 모를 테니 뭔가 너무 뜬금없다는 느낌을 받았습니다 (물론 나중에 전체를 본 사람들의 말을 들어보니 나오는 내용이긴 함) 그걸 떠나서 재미 면에서는 최고였다고 생각합니다. 렌고쿠가 왜 부모님과 그런 회상을 했는지 이런 좀 더 가미된 설명이 있었다면 참 좋았을것 같네요 만화책과 동일하게 만들다보니 그랬겠지만 아무튼 속편이 더 기대됩니다.
# 1,미드소마,별로... 뭘 말하려는지도 모르겠고  뭔가 감독이 있어보이고싶었나봄. 노래만 으스스한게 좋음
# 1,반도,정신나간 신파극. 지겨워 미치겠다
# 1,아수라도,어떻게 21세기에 이런 영화가 나올수있지 .. 정말 장면 하나하나가 감동이었고 배우들 연기와 액셕씬은제가 이때까지 봐온 어떤 영화와도 비교할수가 없네요감독이 누군지 정말 궁금해지네요
# 7,미나리,결말이 많이 아쉬웠어요
# 8,메멘토,낯선 편집 기법, 영화를 보는 내내 지루할 틈이 없다.
# 2,리스타트,개재미없음 돈이 너무아깝고 졸다나옴
# 10,300,비록 오리엔탈리즘에 찌들은 영화였지만, 장면 자체는 우수했습니다.
# 2,고질라 VS. 콩,환불받고싶다....
# -----------------------------------------------------
# 10,반지의 제왕: 왕의 귀환,
# 10,블레이드 러너 2049,모든 것이 환상적이었습니다.
# 10,거룩한 계보,예승이 아빠는 초범이 아니였다
# 8,아가씨,저는 기대를 언하고 봤는데 괜찮게 보았습니다, 특히 배우분들 연기가 정말 좋아요
# 10,고질라 VS. 콩,콩  이 쓰는 도끼는 이름이 뭘까
# 10,미션 파서블,오랜만에 정말 재밌게 봤습니다 ㅎㅎㅎ
# 10,인천스텔라,
# 10,아수라도,독특한 맨손 액션씬
# 2,최면,왜 항상 한국 공포영화들은 개봉 전에 그렇게 기대하게 만들어놓고 개봉만 하면 뒷통수를 치냐...
# 10,라야와 마지막 드래곤,아이와 함께 보았는데 너무 재미있었어요.
# -----------------------------------------------------
# 7,고질라 VS. 콩,펑펑 터지고 고질라는 많이 맞고 콩은 소리지르고 메카고질라는 강력하다
# 2,저스티스 리그,레이피셔가 분노한 이유를 알겠음 워너, ㅈ스웨던 OOO. 블핑의 마지막처럼 때문에 2점 줌
# 10,1987,힘들게 이뤄낸 민주주의 소중해
# 7,아이,있는 그대로를 가감없이 보여줌으로서 현실문제를 제기한다..류현경 욕쟁이였군..^&^
# 10,택시운전사,대한민국의 민주주의를 지켜내신 분들께 깊은 감사와 존경을 보냅니다
# 10,톰과 제리,제 평점 보시고 꼭 꼭 꼭  보세요 알겠지요 넘나  재미  있어요.ㅋㅋㅋ 꼭 꼭 꼭 보시고 진짜 재밌으니까 재밌다는 말밖에 안 나오네요 알겠지요 꼭 보세요 톰과제리 정말 잘 만들어진 거 같고 그리고 스토리와 연기연출 영상미 OST까지 다 정말 아름답네요 제 그러면 여기서 마치도록 할게요 안녕히 꼭 보세요
# 9,중경삼림,사랑에도 유통기한이 있다면 좋겠다. 임청하의 마지막 영화. 지금봐도 특이한 캐릭터를 연기한 왕페이. 훈남경찰의 대명사가 된 양조위의 663. 시대를 앞서간 연출을 보여준 왕가위
# 10,잭 스나이더의 저스티스 리그,와 그냥 완전 다른 영화네... 이대로 나왔으면 대박이었을텐데... 대박임
# 1,아수라도,인터스텔라 급 연출...대한민국 최고의 ,SF영화
# 1,몬스터 헌터,내가 뭘본거지....
# -----------------------------------------------------
# 8,사랑은 비가 갠 뒤처럼,고마츠 나나 때문에 봤는데, 잔잔한 재미까지 있었습니다.ㅎ 아재로서 점장은 심적 갈등상황이 충분히 공감됐어요
# 8,고질라 VS. 콩,레전더리픽쳐스 중국자본 이젠 막을수가 없는듯..  일본사람 악역으로 쓰는건 중국의 의도겠지..
# 10,검객,0점 다 페미네 여자 목잘랐다고 0점주는듯좋나재밌습니다 재미없다는 애들은 존윅도 재미없다고 느끼는 애들이에요~
# 8,히트맨,코믹하고 볼만했는데 후반에 마무리가  좀 아쉽네요 ㅠ 그냥 맘 다 비우고 내용 신경 안 쓰고 보면 또 재밌는거 같기도 하고 ㅎㅎ
# 10,더 박스,대박! 고생 많았어요 여러분! 고생 많았어요 박 찬열!~~
# 1,원더 우먼 1984,모든 것을 뚫는 수 많은 창들과 모든 것을 막는 수 많은 방패들이 뒤섞인 모순 풍년의 난장판 구성과 스토리. 런닝타임이 긴데도 불구하고 중간중간 뭐가 많이 생략된 것처럼 스토리가 끊긴다. 그러면서 또 지루하고, 오그라질 정도로 유치하면서 억지로 감동을 짜내려는 한국형 신파까지 비볐다. ㅋㅋ 배우들의 발연기도 아주 일품이고 주인공의 점프하고 착지를 하는 모습들은 마치 오래전 홍콩 무협 영화 같다. 그리고 슬로우 모션 과하게 넣는 건 DC의 시그니쳐야? 더 지루하고 현기증 나서 못보겠다. DC영화를 보기 전에는 공황 약을 꼭 챙겨먹어야겠다.
# 8,소림축구,볼 때마다 재밌다. 이젠 주성치가 주연으로 나오는 영화는 못보는 걸까
# 10,더 박스,이 영화는 사운드트랙이 좋아서 정말 좋아요! 영화 제작진과 찬열은 놀라운 일을 해냈습니다!
# 10,더 박스,이것은 좋은 영화입니다! 찬열은 좋은 배우이고 재능 있는 음악가예요. 너무 좋아요, 다들 보세요!!!
# 10,포레스트 검프,저도 모르게 눈물이 왜 날까요
# -----------------------------------------------------
# 8,내가 사는 이유,재미있었는데 기억하는 이들이 많이 없네
# 7,떠날 때는 말없이,60년대 사회적 모습과 배경과 가치관이 보인다
# 7,아수라도,아쉽다저예산 영화 치고는 꽤 잘 만들었네좀 더 재밌게 만들 수 있었을텐데...걍 나름 킬링타임용으로 볼 만 함우리나라 영화도 투자좀 하자...
# 7,5인의 해병,61년도작이란걸 감안하면 잘만든 영화
# 1,7광구,좌좀은 머갈통 속에 논리회로라는게 아예 없냐? ㅋㅋ
# 9,태극기 휘날리며,대적관이 이상한 대깨문들이 꼭 봐야하는 영화
# 10,버드 박스,대박!!!!말론 설명안되는 영화임
# 6,프리즌 이스케이프,실화와 긴장감 연출만으로 볼만함
# 10,김복동,
# 7,무뢰한,가오가 현실성을 떨어뜨림.남주 칼맞았는데 경찰차보고 그냥 가라고 손짓하는거 보고 좀 깸
# -----------------------------------------------------
# 2,검객,1대100 ㅋㅋㅋ  아 시대극 진짜 지겹다 뻔한내용들
# 8,미나리,영화보고 감동이 없었다면 너무나 당연한 우리의 이야기를 담담하게 풀어냈기 때문인듯하다. 다시 돌아보면 하나하나 우리의 작은 추억들이 묻어 있는 영화. 영화 속 그 때의 나를 다시 생각해보면 여운이 남는 영화.  미국에서 만든 영화에 대한민국이 들어가 있는 영화. 미국사람이 만든 대한민국 영화.
# 10,인사이드 아웃,나도 모르게 내 안의 핵심기억을 메모장에 적어봤다.
# 10,지금, 만나러 갑니다,그립습니다 다케우치 유코
# 10,잭 스나이더의 저스티스 리그,이게 영화지!!! 후반부는 화장실에 읹아서 봐야 했습니다. 계속 지려버려서...
# 2,26년,답답해 OOO 줄 2점도 아까움
# 2,26년,답답해 OOO 줄 2점도 아까움
# 8,나를 찾아줘,재미있었음 이영애씨의 연기도 좋았고 오랜만에 하는 복귀작인데도 예전 연기그대로 보여줬다 ㅠㅠ 감사해요
# 10,고질라 VS. 콩,우리는 콩진호가 필요하다
# 10,고질라 VS. 콩,우리는 콩진호가 필요하다
# -----------------------------------------------------
# 10,걸스 오브 막시,누구나 꼭 봐야할 영화,
# 10,히트맨,웃기기로는 극한직업 열배.
# 5,해피뻐스데이,첫 장면부터 기겁하며 보는데 계속 기겁할만한 스토리와 장면들이 쉴새없이 나와서2시간동안 실컷 기겁함. 아놔ㅡ 근데 이 몰입감은 무엇?!
# 3,직쏘,어떻게 이렇게 잘만든 캐릭터를 개 OO같은 감독들이 맡아서 시리즈를 베려놓는지 도대체 이해를 할수가 없다
# 10,조디악,내가 봤던 스릴러물 중에 탑3안에든다. 긴 러닝타임에도 하나도 지루하지않았다. 마지막 부분에 사진을 손가락으로 가리키며 확신한다고하는 장면은 정말 소름이 돋았다. 그리고 두 사람이 눈을 마주봤을때 리의 눈빛이 진심을 말해준다.
# 10,힐빌리의 노래,영화 시작 무심코 보다가 음악에 한스 짐머가 있어 놀랐다. 영화를 다 보고 왜 참여 했는지 알겠다. 대부분의 이야기에서 불우한 가정사는 괴물이 만들어지는 이유가 돼 나처럼 불안정하고 힘든 가족사를 겪으며 자라온 사람에겐 정말 족쇄와도 같다. 포기하지 않고 나도 '잘'살 수 있다는 희망을 갖게해준 영화. 자라나는 비슷한 환경의 아이들에게 좋은 영향을 줄거같다. 누군가의 삶의 방향을 바꿀 수 있다는 것, 이것이 영화가 존재하는 가장 큰 이유 아닐까.
# 10,다크 나이트,빠른 사건전개가 맘에 든다. 다만, 어장관리녀 레이첼이 영화속 미인이라는 설정이 가장 이해 안가고 몰입이 힘들었던 부분. 그리고 이 영화의 주인공은 베트맨이 아니라 조커이다.
# 9,잭 스나이더의 저스티스 리그,이전의 저스티스리그는 가짜고 이게 진짜다
# 10,프리즌,한석규 연기 ㅎㄷㄷ시간 가는줄 모르고 봤네요  쵝오
# 10,싸움의 기술 2,재밋어요 1,2다봣는데 괜찮네요. 재밋어서 담이야기인3이 기대되네요 재밋습니다.
# -----------------------------------------------------
# 10,귀를 기울이면,한 때는 저도 꿈 많던 소년이었는데 지금 현실과 타협해 살고 있는 것이 살짝은 씁쓸했습니다.영상미도 좋았고 딱 그 나이 때 할 수 있는 풋풋한 사랑이야기였던 것도, 서로에게 영향을 받아 발전해나가는 것도 좋았어요.큰 감동이나 반전은 없지만 보는 내내 미소 지을 수 있었습니다.후속편이 나왔으면 좋겠다는 개인적인 생각...
# 1,비치,뭘 말하려는지는 알겠는데 상당히 내용이 조잡하다..
# 8,스파이의 아내,통나무는 땔감으로 쓰이다 재가 될 뿐, 누구도 사과하지 않는다.
# 10,킹덤 오브 헤븐,정말 최고의 명작!!!
# 1,사일런트 워,노잼중의 노잼...
# 7,블루 아워,심은경은 점점 대배우가 되어간다...일본영화 싫어한다면 최악의 선택일수도
# 10,극장판 귀멸의 칼날: 무한열차편,영상미가 훌륭해서 보기 좋았습니다원작과 같은 내용임에도 좋더군요작붕도 없어 근래 극장판애니 중 가장 잘 만든 작품이 아닌가 싶네요
# 2,뺑반,시나리오나 감독 수준이 엉망인데 류중일 조정석  연기가 전부인 영화
# 9,고질라 VS. 콩,알고보니 트루먼 쇼의 주인공 트루먼 신세였던 킹콩의 킹콩 쇼.콩VS고질라는 최고의 이벤트다
# 10,테스,그시대에  풍경화같은 그리고  자연미인?테스의 연기  아름답다??내 두살누나가 중학생되고 첫 학교단체 영화관람했던 영화라  더  소년에가슴에  기억하던  테스
# -----------------------------------------------------
# 10,태극기 휘날리며,감히 평가하지 못할 영화에 감히 살아갈 자격도 없는 벌레들이 있네니네같은 벌레들 살라고 희생하고 나라지킨 줄 아냐 영화 찍는 배우들조차도 겸손하고 엄숙하게 찍었는데 지들이 뭔데 평가를 근본도 없이 하냐 진짜 니네 주변 사람들이 불쌍해진다이런 영화를 만들어주신 많은 손길들과 편하게 잘 먹고 살 수 있도록 희생되고 희생해주신, 속에 차지 않으실 후손이지만 너무나도 감사합니다.
# 9,툴리,꽤 나왔었던 소잰데도 나는 왜 영화를 보고 마음이 쿵 내려앉았을까
# 10,죽여주는 여자,돈이 많은 노인이든 없는 노인이든...자식은 자식의 가족이 있고 ...그만 살 고 싶을 수 있다는 생각..너무 눈물이 난다..나에게는 오지 않았으면 좋겠지만 누구에게나 노인기는 온다....
# 7,주디,오즈의 마법사 속 도로시와 그 시대 할리우드에서 살아가던 아역배우 주디를 모른채 온전히 바라보는 주디 갈랜드의 삶.
# 10,녹터널 애니멀스,수작임. 배우들 연기도 훌륭하고 영화에선 보기 쉽지 않은 액자식 구성도 좋다. 볼때마다 소름이다.
# 10,퍼펙트 케어,올해의 영화
# 7,파이란,사랑에 이유가 어딨냐고 하지만... 강재의 사랑이 다소 뜬금없이 느껴진다
# 10,승리호,킬링타임으로 좋습니다
# 8,콩: 스컬 아일랜드,cg도 좋고 괴수영화 종류 인데도 불구하고 스토리도 괜찮았습니다 한번쯤 볼만한 영화입니다.
# 10,12피트,재밌어서 평점 주러 왔는데 댓글보니 다른 분들은 재미가 없었나보네 전 한번에 몰입해서 재밌게 봤어요 동생이 첨에는 왜저렇게 맘이 삐뚫어졌나 했는데 하나씩 이야기가 풀어질수록 이해가 가고 그역 배우분이 연기도 잘하셔서 기억에 남았어요 두분다 연기 잘함요
# -----------------------------------------------------
# 10,타이타닉,이영화를 뛰어넘는 작품이 있을까 싶다 내생에..
# 1,몬스터 헌터,망한 영화는 이유가 있다.
# 10,극장판 귀멸의 칼날: 무한열차편,렌고쿠 살려내ㅠㅜㅜㅜ
# 10,죽여주는 여자,너무좋았어요굳굳굳굳인생영화
# 6,윤희에게,잔잔하고 담담함. 지루할 수 있음.
# 10,퍼펙트 케어,10점안주려다 선어오브비치 위치 여자 진짜 대져서 10점준다!!!! 망할냔!!!!
# 6,미션 파서블,이영화보면서 느낀거 배부름사람들이 누어서 땡강피우면 나라에서 해주는 나라...
# 10,아수라도,아주잼있었어요 강추합니다
# 10,내 여자친구를 소개합니다,
# 10,주식회사 스페셜액터스,무스 손짓 하고 다녀야지ㅋㅋ
# -----------------------------------------------------
# 10,스물,대사들이 GTA5 주인공들마냥 제정신이 아니네요오히려 재밌었어요
# 10,크리미널 스쿼드,역대급 영화다.. 이 영화를 이제서야 봤다니...
# 6,뱀파이어,당시로 보면 괜찮았지만, 이제 보면 좀 유치.
# 4,볼케이노,젊은년이랑 바람나는건 선넘었지 ㅋㅋ 50대할배랑 20대여자랑 재난극복했다고 OO이를비벼
# 6,쓰리데이즈 투 킬,4점대-살면서 굳이 안봐도됨/5점대-봐도그만 안봐도그만/6점대-볼만하고 재미가 적당한수준/7점대-추천해줄만한 영화/8점대-스토리,연출,연기 다 잘갖춘 영화/9점대-스토리,연출,연기 몰입감까지 시간순삭 강추영화/10점대-명작 살면서 꼭 봐야될 영화 (개인적인 생각입니다) 평점6.3점-정통액션이 아닌 가족영화에 액션이 가미된 영화라고 보면될듯하다. 다소 지루할 순 있으나 영화 중간중간에 코믹적인 부분과 따뜻한감성을 옅볼수있는 영화다. 그리고 엠버허드 대사가 영화의 핵심 대사들인데 집중 할수가없다 미모가 너무 뛰어나서... 넘사벽이다.
# 6,폴터가이스트,특수효과는 칭찬할만하지만...공포라고 느낄부분은 전혀 없었다 공포가 아니고 가족영화 수준
# 8,중경삼림,존나 매력있는 영화...
# 10,더 박스,잘있어요 정말 좋아해요.
# 9,아수라,동기를 만드려고 길게 서론을 끄는것 보다, 동기 없는 난장판이 더 즐길만 했던것은 나뿐인가보다. 등장인물에 몰입하고싶지도 않고 자세한 동기가 궁금하지도 않다. 그저 긴박한 상황에 몰입하고싶다 하면 보면 된다. 나에겐 별미였지만, 대중의 입맛에는 한참 떨어져있는 맛인듯.
# 9,내셔널 갤러리,몇 년전 다녀왔던 런던과 박물관의 기억이 새록새록 떠오르네요. 3시간 동안 도슨트를 들은 기분이예요. 정말 좋네요.
# -----------------------------------------------------
# 10,검은 사제들,다시봐도 명작입니다. 속편 만들어주세요.
# 8,고질라 VS. 콩,여러분 잊지마세요. 이 영화는 반드시 아이맥스로 봐야 하는 영화 입니다.
# 4,증인,2심재판 이후는 너무 수준이 낮아지네 어휴
# 10,죽여주는 여자,먹먹하다.. 윤여정 배우님만이 해낼수있는 연기..동시대에 살고있음이 감사한 배우다.
# 10,검객,넷플로 봤는데 상영시간이 100분이긴 하나 2시간 넘게 봄. 무술연기가 너무 세련되고 멋있어서 한 장면을 5번 넘게 돌려보느라.. 자비없이 거침없는 칼, 괜히 무도인이랍시고 답답하게 정공법만 쓰는 게 아닌 이기려고 머리쓰면서 하는 자유로운 칼싸움. 장혁 정말 멋있다.
# 1,나이트 언데드,좌파 토마스 크래취만 쓰레기 배우에 쓰레기 영화
# 10,잭 스나이더의 저스티스 리그,하....말이 필요없다
# 10,마지막선물...귀휴,즐라탄 연기 잘하네..
# 1,퍼펙트 케어,이런 쓰레기 영화는 처음봄..
# 10,더 로드,아라곤의 두번째 원정은 참 많이 아프네요
# -----------------------------------------------------
# 10,악마를 보았다,영화 아저씨랑 같은 달 사이로 개봉한 기가 막힌 대작.
# 10,그린 북,오랜만에 정말 좋은 영화 봤네요.
# 9,영웅본색,cgv에서 코로나 때문에 극장 재개봉을 해서 봤어요. 영화를 다 본 후 퇴장하며 같이 영화를 본 관객들을 보는데 아저씨 아줌마들인데 다들 추억에 잠긴 이야기와 표정이었어요. 나도 훗날 내가 감명 깊게 본 영화가 재개봉 하는 날이 오겠죠?
# 2,좀비랜드: 더블 탭,?ㆍㄴㆍㆍㅊㆍㅣㆍㆍㆍㅈㆍㆍㅗㆍㆍ
# 10,반지의 제왕: 반지 원정대,20년전 영화라고? 말이안되잖아.. 판타지영화중 원탑이다
# 2,음양사 : 청아집,이렇게 못만들기도 힘든데.. 대단하다...일본+중국 합쳐서 저렇게 망치기도 힘든데...대다나다
# 10,반지의 제왕: 두 개의 탑,판타지 최고의영화.. 볼때마다 소름돋네요
# 2,세자매,보기 매우 힘든영화입니다
# 1,최면,이게 영화를 본건지 뭐를 본 건지 감동도 재미도 없는 개 씹 노잼 영화
# 9,리틀 포레스트,ㄹㅇ 9 점준이유가  감독이 채식주의자라 재미있고 힐링되긴 한데 몇개는 맛없어보이고 고기넣으면 ㄹㅇ 명작인데 진짜 감독님 후속편은 고기좀 넣어조요
# -----------------------------------------------------
# 10,잭 스나이더의 저스티스 리그,워너가 처음부터 잭스나 의견대로 DCEU 구상했으면 마블 저리가라 했을텐데....
# 10,무간도,무간도를 보니 신세계는 OO이었네
# 10,더 박스,신나서 흥 참고 봤습니다
# 2,최면,진짜 뭐지 마트에서 4D맥스 무서운거 보는느낌 딱....;;
# 8,인비저블맨,뒤로갈수록 그녀를 의심했던 나도 미안해진다.
# 10,12피트,평이 왜이렇지? 눈을못땔만큼 흥미진진했어요재밌던데 왜평점이 이런지이해안됨좋은평점 알바에 속은적은많지만 나쁜평점에도 알바가있는건지..ㅎ
# 10,더 박스,찬열이는 항상 내 마음과 생각을 선하게해. 이 세상은 찬열이에게 감사하고 너의 성공을 축복해야되.
# 10,소울,
# 10,극장판 귀멸의 칼날: 무한열차편,애니에 애자도 몰랐던내가 이걸보고 엄청 울었다... 쿄주로 사랑해여
# 10,잭 스나이더의 저스티스 리그,
# -----------------------------------------------------
# 10,더 셰프,너무너무 재밌게본영화
# 1,아수라도,보다가 민망 할 정도로 어색한 연기에....ㄷㄷ
# 7,미션 파서블,개그코드는 좋다 액션도 좋다 다만 남배우가 너무 가볍게 연기한다 그게 일장일순 있지만 일단이며 왜그렇게 보였는지는 표정연기가 좀더있었으면 한다
# 6,언노운 솔저,오세요 핀란드로...전쟁영화도 담담한 곳
# 10,더 박스,Good movie!!
# 1,반도,전작의 흥행에 기댄 1점도 아까운 졸작이다
# 2,블러드 스크린,슬래셔 영화는 맞는데약간 삼류식 잔인 연기 존못내가 이걸 돈 주고 봤다니 여기 알바천국이네 ㅎㅎ
# 8,퍼펙트 케어,한국의 신파, 조폭, 고래고래 소리지르기....등등 천편일률적인 스토리를 떠올린다면 이런류의 외국영화는 20년정도 앞서가있다
# 1,아수라도,대학교 영화동아리에서 만든 영화 수준임
# 10,고질라 VS. 콩,오늘 IMAX로 봤는데 지구 공동설이나 하이퍼루프 같은 것이 표현되어 잼났습니다. 영상은 뭐 완전 만족.
# -----------------------------------------------------
# 10,고질라 VS. 콩,역시 영화는 이렇게 치고박고터져야지
# 1,승리호,이 영화는 평점 높게 주는 알바가 있는건지, 그냥 관객 수준이 떨어지는 건지 이런영화에 10 점을 준다니 충격이 말도아니다. 제작비 엄청 들었을 거 같은데 스토리 때문인지 이영화를 보면 송중기 연기가 발연기로 보인다. 외국배우 연기력도 장난없이 발연기에다, 김태리 혼자 연기하는걸로 보여지고 업동이 로봇 유해진 목소리는 왜 했는지 모르겠으며 스토리가 B급보다 더한 C급영화수준인데 CG가 멋있다고 십점을 주는건 그냥 영화를 볼줄 아는 사람이 맞는지 의심스럽다. 불면증에 특효약일정도로 졸렸다. 제일 충격인건 늑대소년 재밌게 봤었는데 그 감독이라는게 믿겨지지가 않는다.
# 2,천군,별 하나도 아까움.   역사외곡
# 4,이터널 윈터 여자 포로수용소,인간승리에 대한 영화가 아니다.소시오패스에 관한 영화다.
# 10,용서는 없다,진짜 반전 ,, 모든 주인공들의 입장에서 봤을 때 다 이해가 되고 정말로 나도 용서할 수 없었다
# 1,클로젯,귀신이 좀비도아니고 방밖으로 못나옴ㅋㅋㅋㅋ 눈뜬자만 본다면서 눈감고 소리내면 좀비처럼 달려드네 ㅋㅋ애플워치 던지는거 개웃겼음 그리고 뭔 이야기가 개연성이없냐 무명퇴마사는 왜 정보도없이 튀어나온건지모르겠네
# 5,사라진 시간,진심으로 배우분들 연기랑 영상미,연출은 10점 주고싶음 근데 스토리가 너무 아쉬움...응가누고 한번만 닦고 나온느낌? 스릴러 향기만 첨가한 스릴러 랄까...주인공이 마지막 까지 기억을 찾으려고 발버둥 치면서 엔딩에서 포기하는 스토리로 갔으면 그래도 궁금하게 남을텐데 이건 포기하는건지 수긍하는건지 기억을 잊고 그 부부처럼 살아갈려고 다짐을 한건지 알 수가 없또용... 예전에 본게 아직도 기억나는거 보니 다른의미로 성공한 영화임ㅋ
# 9,잭 스나이더의 저스티스 리그,좆스웨던은 대체 영화에 무슨 짓을 한거냐?
# 10,미션 파서블,와 너무재밌게봤어요 진짜웃기고 김영광 넘귀엽고 멋잇음  2편 3편 계속 나오면 좋겠어요
# 10,더 박스,일단 노래가 다 너무 좋음 선곡도 좋고 특히 A Sky Full Of Stars 드럼부분이 신나고 목소리랑도 넘  잘어울려서 신나고 좋았음 Happy가 제일 지훈의 목소리와 잘어울리는 것 같았고 마지막 Break Your Box 가사도 좋고 제일 중독성 있었음 노래로 각 지역을 다니면서 그 지역에 문화나 음식들을 보여줘서 신선하고 좋았음 처음 보면 스토리가 뻔할 순 있지만 더박스 특유의 느낌이 들어가서 뻔하다는 느낌도 들지 않음 노래도 좋아하고 영화도 좋아한다면 보는걸 추천.
# -----------------------------------------------------
# 10,세상을 바꾼 변호인,RBG 그녀를 기억하며
# 10,잭 스나이더의 저스티스 리그,아..이런 명작을 개 쓰레기로 만드는것도 재주네요.세컨 제목으로 "저스티스 리그의 역습" 어떤가요.
# 7,고질라 VS. 콩,짧은 러닝타임인데 지루해지는 스토리에 여기갔다가 저기 갔다가 정신 산만한 카메라워크... 지친다....몬스터들간의 박진감넘치는 격투신은 뭐 하고 싶은지 알겠다만...
# 6,크로우,플롯은 꽤 단순한 복수극이지만 영화 전체적으로 마치 메탈음악의 뮤직비디오를 보는 것 같은 나름의 분위기가 있다
# 10,소년시절의 너,음악부터 몰입까지...연기라는 생각없이진실..저기 어딘가에 진짜 벌어졌을듯한..연기 미쳤다..왜 이제 봤을까...
# 2,써니,그녀들의 우정에 감정이입제로 결말은 몬가 모욕적 오래전 영화이긴하지만 이런영화가 흥행했다는게 놀랍다 작위적이다 너무나
# 1,브이 포 벤데타,겉멋만 있고 내용은 없는 이런 한심한 영화 추종하는거보면, 본인이 되게 대단한 사람인것처럼 느껴들지시나봐?ㅋㅋㅋㅋ
# 10,잭 스나이더의 저스티스 리그,이번에 새로 개봉한 영화 잘보고갑니다 마블은 영화안내는데 디씨는 내서 좋네여
# 10,연평해전,서해 수호의 날이라 생각나서 왔습니다
# 10,제이슨 본,재밌게 봤다 예전에 비해서 긴장감은 없다
# -----------------------------------------------------
# 10,어바웃 타임,그냥 생각날때마다 보는 내 인생 최고의 작품. 볼때마다 새롭게 느껴지는 감정들이 너무 뭉클하고 보는내내 미소를 띄게된다.. 나도 모르개 띄고 있는 미소, 설렘, 감동, 슬픔.. 최고라는 단어로는 부족할 정도로 너무나 멋진 영화
# 6,새해전야,그냥 가볍게 보기에는 괜찮은듯
# 10,잭 스나이더의 저스티스 리그,2017년도 저스티스 리그는.. 2021년도 스나이더판 저스티스 리그의 예고편이었다라는걸 비로소 알게되었다. 무엇을 상상하던.. 최고의 기대감을 선사한다.최고다!!!
# 10,1987,숨기려해도 진실은 밝혀진다.
# 1,댄서의 순정,짱개의 순정 멋지다 개옥아 ㅋㅋ 개옥이 딱임
# 7,열혈남아,
# 10,잭 스나이더의 저스티스 리그,감독의 세계관. DC가 가진 암울하면서 진중한 영상. 영화관에서 본 영화가 아닌 다른영화다. 4시간이 어떻게 지나갔는지ㅜㅡ 후속편 빨리 만들어라. 딸을 잃은 잭스나이더에게 위로를 보내며 이런 영화 만들어 줘서 고맙다.
# 10,그것만이 내 세상,재밋다.. 벌써 몇번째인지 모를만큼 재밋다
# 8,최면,감정이나 심리상태의 공포감이 장난 아님 재미있었음
# 10,소울,인생영화.. 말이 필요 없다.
# -----------------------------------------------------
# 1,천군,영점은 못 주는 거냐 ㅋㅋ 짱개영화
# 8,몬테크리스토: 더 뮤지컬 라이브,촬영을 꽤 잘함! 그냥실황중계보다 몰입감있으나 좀멀리서 보면좋겠는데 자꾸 가까이잡아서 아쉬운점도있었음.배우들 연기 노래 최고임
# 10,고질라 VS. 콩,지금까지 몬스터버스 영화중에 최고인것같아요 많이 잔인하거나 혐오스러운 장면도 많지않아 가족들과 보기에도 좋은것같아요 (i max로 보시면 두배로 재밌습니다!!)
# 10,블랙,교수님이 보여주셔서 봤는데 엄청움..눈물 제조기
# 8,박쥐,욕망의 끝을 보고싶다면.
# 4,서바이브 더 나잇,시나리오가 너무 지리멸렬 ㅠ
# 10,1987,2021년 가해자들은 아직 살아있다
# 10,벤자민 버튼의 시간은 거꾸로 간다,내 인생 최고의 영화다. 봐도 봐도 가슴 먹먹해지는...판타지 별로 안좋아하는데 이건 철학 영화에 가깝다. 아들을 잃은 시계공의 간절함에, 사랑하는 어린 연인을 품은 여인의 모습에 눈물을 쏟았다.인생 곧 사랑은 영원하지 않음이 아쉬울 뿐이다.
# 10,고질라 VS. 콩,진짜 스토리 cg다완벽
# 1,더 박스,이제 좀 고마하자 좀 제발
# -----------------------------------------------------
# 10,고질라 VS. 콩,긴장감 영화보는내내 오져요가슴이 쿵쾅
# 10,고질라 VS. 콩,고질라와 콩 둘 다 정말 멋졌습니다.
# 10,스물,누구에게나 있었던 스물(이 영화는 스물이 좀 많이 지난 사람에게 더 와닿는 영화이다)미래는 불안하고 안개 같은 그 시절, 사랑을 꿈꾸지만 사랑에 서툰하지만 그 시기를 함께 할 친구가 있어서 싱그러웠던 스물을 잘 담아내었다. 보는 내내 입가에 미소 지으며 봤던 스물의 풋풋함이 코끝에 진동하는 수작이다. 배우 연기. 연출 모두 좋았다.
# 8,트라이앵글,끝없이 반복되는 악몽처럼..
# 4,피아노,평점읽어보고 최대한 편견없이보려고 노력했는데... 너무 더러워서 그냥껐다ㅜ 세상이변한건가 난 30대인데 너무 정서에안맞는다
# 1,가발,오래 전에 봤는데 잊혀지지를 않는다 내 인생에서 본 영화들 중에 가장 재미없던 영화 베스트1위!
# 8,고질라 VS. 콩,재밌었습니다. 겁나게 치고박고 싸우는데 속이 다 시원하더라구요
# 8,인천스텔라,인천스텔라 후속작으로 '제천스텔라' 기대해봅니다 !
# 10,잭 스나이더의 저스티스 리그,집에서 VOD로 결제해 봤는데..2017년 저스티스리그를 봐서 정말 기대가 크지 않다가 눈이 뜨인느낌.수작은 아니여도 평작이상!망해가던 DC의 한줄기 빛.4시간이 지루하지 않고 액션씬이 볼만하다.
# 10,고질라 VS. 콩,고질라vs콩중반부에 에이펙스에서 몬스터 제로에 두개골로 메카고질라 탄생고질라 메카고질라에게 존나 뚜까맞고콩은 전기 충격기로 살아나고질라 와 한팀 되어서메카고질라 죠지네!간만에 괴수영화 재밌게 봣네해상 전투씬도 화려하고시간순삭임!
# -----------------------------------------------------
# 8,중경삼림,처음에는 잘 이해하지 못한 부분이 많았는데 보면 볼수록 영화의 분위기에 빠져들었어요
# 4,언브로큰,1시간 40분간 그리스도에 입봉하는 영화를 보고 있었다니ㅡㅡ
# 10,잭 스나이더의 저스티스 리그,개오짐  개오짐  개오짐  개오짐 개오짐  개오짐  개오짐  개오짐 개오짐  개오짐 개오잼 개오짐  개오짐
# 10,트웬티 해커,스토리 연기 영상 모두 완벽해서 시간가는 줄 모르고 봤습니다
# 2,히트맨,삼류다 이건...이게 잼있다고? ㅎ
# 4,아수라도,처참하군요.. 90년대 초반 영화인가요? 연기 연출, 특히 무술 감독이 없나요? 배우들이 별론가요.. 오히려 보는 사람이 미안해 질 정도입니다! 배우님들 힘내세요
# 6,이별의 아침에 약속의 꽃을 장식하자,그 뭐냐 브레이브스토리 보는느낌
# 8,고질라 VS. 콩,액션은 무섭더라. 무엇보다 홍콩이 쑥대밭이 되어 가는데, 도로에 차들은 퇴근하기 바쁘더군. 사람들이 도망을 안 가.
# 1,배틀쉽,오히려 외계인을 응원하고 싶더라
# 1,천군,뒤로갈수록 별로임 역시..
# -----------------------------------------------------
# 10,극장판 귀멸의 칼날: 무한열차편,렌고쿠 ... 멋잇다 .... 하
# 8,디 아더 사이드,깜짝깜짝 놀랐네요 ㅋㅋ 재밌게 봤습니다
# 4,인터스텔라,솔직히 진짜 솔직하게 잼있는지 모르겠어요 하도 흥행해서 극장에서 봤는데 너무 지루하고 딱히.... 뭐랄까 사람들이 와 대단하다 잼있다해서 덩달아서 그런듯 해요..영화관에서 보는데 3분의1 보다가 나가던데... 거짓말 아니구 ㅜㅜ 검색해봐도 나오다시피 미국에서나 해외에선 흥행하지 못했는데... 한국에서만 흥행한 이유가 궁금..허세꾼들이 너는 이해못했다 약간 이런 영화... 개인적 의견입니다
# 1,미나리,일보고 밑안닦고 나온 듯한 결말. 연기도 그닥... 내가 뭘 본거지?
# 10,고질라 VS. 콩,오랜만에 영화관 나들이 가서 눈호강 귀호강 했어요코로나 때문에답답했던 마음도 뻥~뚤렸어요꼭 보세요
# 8,콩: 스컬 아일랜드,약간 고개를 갸우뚱하게 하는 장면들은 없지 않은데 뭐 암튼 전체적으론 괜찮은 오락 영화.
# 10,고질라 VS. 콩,간만에 스케일이 큰 영화봤습니다!
# 10,고질라 VS. 콩,스토리는 제껴두고.  동생이 형한테 깝치다가  동네 양아치 형 나타나니까 형제애 발동하는 그런 느낌이었음ㅋㅋ 액션최고
# 8,조제, 호랑이 그리고 물고기들,
# 10,반도,스토리가 아주 살짝 아쉬운거 빼고 너무너무 완벽했다 액션이든 좀비든 징그럽고 무섭고 으으 추천작
# -----------------------------------------------------
# 7,패신저스,그냥 적당히 혼자 시간때울때 보기 좋은 우주영화에요.인터스텔라같은거 기대하지 마시고 가볍게 보시면 됩니당 근데 주의하실게 배드신이 15세이용가정도는 되보이는데 12세더라구요
# 2,세상의 모든 디저트: 러브 사라,예고편이 다였다... 영상미 예쁘고 소재도 좋았는데 개연성이.... 이해를 할수없고 잉??이러면서 봤던....너무 어이가없어서 감독을 찾아본경우는 처음이었다
# 8,살인마 잭의 집,잘만듬. 근데 포스터 중국당면 엽떡들어가는중으로 보임;
# 10,트웬티 해커,어제 영화보고 이제서야 글을남기네요 너무재미있게 잘 보았어요 임나영 연기잘하던데요 스토리도 좋고 무엇보다     임나영 연기하는 모습자주자주 보았으면 합니다.
# 10,싱글라이더,결말 모르고 보세요 여운이 남네요
# 10,엔젤 해즈 폴른,막판 g20 구석탱이 찐따 나온거땜에 눈썩은거 빼면 완벽했어요^^
# 10,에브리원 세즈 아이 러브 유,뭔가 가벼운듯 하지만 삶과 사랑에 관한 깊고 진한 울림이 있는 영화.믿고보는 우디앨런!
# 10,아수라도,감독은 마지막 장면에서 관객에게 질문을 던진다.오히려 우리가 아수라의 세상에 살고 있는건 아닐까
# 10,어느 가족,우리 사회는 다양한 형태의 가족이 있다. 사회의 일반적 시선에서 바라보면 어긋남 투성이지만 영화를 보던 나는 어느새 이 가족을 응원하고 지지하고 있었다.
# 8,고질라 VS. 콩,킬링 타임으로 최고..근데 메카 고질라 음료수로 막는건 너무한거 아니냐ㅋㅋ..
# -----------------------------------------------------
# 10,내 어깨 위 고양이, 밥 2,요즘같은 시대에 어울리는 영화다!우연희 가족이된 반려묘와 교감 사랑을 통해서 불행하고 암울하고 약물 중독자로 살았던 주인공에게 밥이라는 고양이로 인해서 중독자의 길을 벗어나고 새로운 삶을 살게된 주인공에게 박수치고싶다 더 공감 가는건 실화를 바탕으로 제작한 영화라서 좋왔다기회가 된다면 원작(책)을 구해서 보고싶다한번쯤은보라고 추천하고싶다
# 10,잭 스나이더의 저스티스 리그,플래시가 주인공 입니다.
# 7,고질라 VS. 콩,큰 스크린을 지닌 영화관이 존재해야 하는 이유
# 10,킬링 디어,영화..와..할말이 없네..
# 1,죽지않는 인간들의 밤,김기천배우 전기고문장면과 94년생드립만 웃겼다. 시실리,차우 B급감성 좋았는데, 이건 C급도 안 된다. 감독이 갈수록 퇴보한다.
# 10,미나리,스토리는 기대 이상으로 괜찮았고, 영상미와 OST가 좋았습니다. 특히나 윤여정님과 한예리님의 연기가 좋았습니다. 한예리님 덕분에 저도 2번이나 울었네요.
# 3,서바이브 더 나잇,이게 영화냐 마지막 장면보고 악당이 착한놈인줄 진짜 스토리 개판 임 무슨 숨바꼭질하냐 가족이 도망쳤다 잡히고 도망쳤다 잡히고 ㅋ 그나마 아주 조금 있는 추격전 1점 조금 있는 스릴감 1점 브루스윌리스 연기 1점해서 3점 준다
# 9,스파이의 아내,정말 가뭄의 단비처럼 오랜만에 완성도높은 일본영화였다. 아오이 유우의 연기도 좋았다
# 8,투 마더스,인간들은 있지도 않은 사랑이란걸 믿고... 또 믿고 싶어한다....
# 10,더 박스,요즘같은 시국에 굉장히 힐링 할 수 있는 영화였어요 노래가 너무 좋았어요
# -----------------------------------------------------
# 10,백조 공주,이거 더빙판 정말 굿...!!! 영상이랑 다 다시보고싶네요
# 10,고질라 VS. 콩,홍콩 그만 부셔 OOO들아!
# 9,트라이얼 오브 더 시카고 7,엄중하고 혼란스럽던 그 시절 그 사건을 가볍고 위트있게 다루는 방식이 오히려 큰 공감과 울림을 준다
# 7,고질라 VS. 콩,
# 10,잭 스나이더의 저스티스 리그,완성도높은 작품!!!!
# 10,더 박스,첨엔 기대를 안하고 봤는데 스토리도 좋고 연기도 생각보더 잘하셔서 재미있게 봤어요!!
# 10,너의 이름은.,"너의 이름은"이 개봉된 16년도는 내 인생에서 가장 기억에 남는 해였다.나는 남들보다 대학 입시가 빨리 끝나 일본어 공부를 할겸 일본 영화와 애니메이션을 찾고 있었는데 그때 누군가의 추천으로 신카이 마코토의 작품들을 보게 되었다. 언어의 정원과 초속 5cm. 그리고 이제막 일본에서 개봉했다는 너의 이름은.특히 "너의 이름은"은 대학 입시에 지쳐있던 나에게 다시 활기를 불어넣어줬다. 너무 감명을 받아서 나는 신카이 마코토 감독이 내한한다는 소식을 듣고 나는 곧장 왕십리 CGV로 달려가 그를 영접하기도 했다. "너의이름은"을 그때도 이미 3번은 봤었고, 이후로 족히 10번은 본듯하다. 리뷰쓰고 또 보러 가야지.그때로 돌아가고 싶다. 코로나 때문에 생기를 잃어버린 지금, 나는 그때가 너무 그립다.
# 10,고질라 VS. 콩,
# 8,아이카,아이카를 짓누르고 있던 애환. 그것이 시나브로 내 안에 스며들었다. 그리고, 엔딩 크레딧이 올라가던 즈음에 나는 아이카가 되어있었다. 그때 문득 깨달았다. 나는 그저 응석쟁이에 불과했음을. 부끄러움을 느낀다.
# 10,검객,킬링타임으로 대만족임. 장혁이 이래 연기를 잘했나?
# -----------------------------------------------------
# 10,미나리,좌충우돌미국농사기!
# 6,고질라 VS. 콩,세리자와 전기충격ㅋㅋㅋㅋ보는 내눈도 충격적이다
# 10,라이언 일병 구하기,우리집도 3형제인데 장남인 저는 군대갔다왔고 둘째는 지금 복무중인데 막내는 군대안갔으면 해서 10점드립니다.
# 10,고질라 VS. 콩,오랜만에 영상미 가득한 영화다운 영화를 보니 즐겁더군요
# 10,노킹 온 헤븐스 도어,울었어 ?잘살고 싶다?지금이순간 행복해지자
# 10,폴란드로 간 아이들,분단국가의 아픔 북한의아픔을 다시한번 느끼게 된 영화입니다 전혀기대없이 봤는데 진한 감동이 밀려오는 영화입니다
# 10,미나리,한이 서린 광기 , 새로운 광기의 시작.
# 10,그린 북,아시아인도 차별하지말아주세요
# 6,레베카,알프레드 히치콕 감독 흑백영화.
# 5,소울,무아지경아저씨등장하면서 세계관 무너짐 그냥 이해하고 쳐봐라식임 영화자체는 괜찮음
# -----------------------------------------------------
# 4,미나리,영화초반부터 지루하고 흥미를 끌수 없게 전개되서 하마터면 영화시작하고나서 잘뻔 했습니다. 스토리 진행도 반전도 계기도 없이 그냥 흘러가다가 결말도 허무하게 납니다. 왜 제목이 미나리인지도 모르겠고, 그냥 일일드라마 중간에 뚝 잘라서 3편정도 본 느낌 그 이상이 아니었습니다. 연기도 딱히 잘한다는 느낌이 없었네요.
# 2,수색역,수색역<불광천
# 10,고질라 VS. 콩,
# 8,잭 스나이더의 저스티스 리그,그전에 우리가 봤던 져스티스는 쓰레기였다는것을 느낄 것이다... 이렇게 잘 뽑아놓고... 개봉을 안했으니...
# 6,모어 댄 블루,음...시간이 아까울 정도의 영화는 아니었으나 작정하고 슬픈 시한부 영화 클리셰는 있는대로 다 때려 넣음 그래서 스토리 개연성이 너무 부실해지고 슬픔만 마구 강요하는 느낌...? 그래도 스토리의 큰 틀은 시한부의 정석 같은 느낌이라 조금 더 힘빼고 담담하게 풀어갔으면 더 좋은 영화였지 않았을까 싶네요 여주는 진짜 사랑스러웠고 오에스티도 좋았습니당
# 8,미나리,기대에 다소 못미치는 영화지만 도전과 좌절, 행복과 비애 등이 잘 어우러진 잔잔한 가족애를 보여주는 영화였네요. 스토리가 좀 지루함을 주기도 했어요.
# 10,더 박스,작은 상자의 무게를 이겨내고 마지막은 세상을 단단한 자신의 무대로 만들어 낸 감동, 찬열의 중저음 목소리로 시작해서 잔잔한 위로처럼 다가온 음악이 점점 가슴 벅찬 황홀감과 감동으로 휘몰아치는 사운드.(마지막은 정말 앉아서 듣기엔 아까울 정도로 발이 가만히 있지를 못 했다..ㅠㅠ) 현 시국에 묶인 두 발을 대신해 우리 눈을 즐겁게 해주는 아름다운 여러 명소를 담은 장면들 그리고 자꾸만 군침 돌게 하는 식도락 포인트까지.. 놓칠게 하나도 없는 영화라고 봅니다 :)
# 10,잭 스나이더의 저스티스 리그,
# 8,매리,좁은 공간 낡은 배에서 악령이 나타나기도 하고 악령에 씌워져 딸 남친 토미도 죽고 마이크, 남편이 죽는데 여주와 두딸은 겨우 살지만 메리악령이 두 딸마저 죽이려 엄마로 변신했나 보다. 다 죽겠네. 지루하지도 않고 빨리 끝나서 좋다. 아빠요 부인 말을 들어서 선장이 3명이나 죽은 배를 사지 말지.
# 10,고질라 VS. 콩,감동이다고질라 킹콩의 포효는!
# -----------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
title = []
link = []
urlstr = 'http://www.yes24.com/SearchCorner/Search?domain=BOOK&query=python' # 예스 24에서 검색창에 파이썬이라고 친 경우
r = requests.get(urlstr) 
#r.encoding = "utf-8" # utf-8이 아니기 때문에 설정하면 오히려 깨짐. (euc-kr임)
bs = BeautifulSoup(r.text, 'html.parser')
titleList = bs.select('p.goods_name.goods_icon > a > strong')
linklList = bs.select('p.goods_name.goods_icon > a')

for titleDom in titleList:
    title.append(titleDom.string)
for linkDom in linklList:
    link.append(linkDom["href"])

print("-- 도서 제목 --")
print(title) # 첫 페이지의 목록들이 나옴.
print("-- 도서 링크 URL --")
print(link)
with open('output/booklink.csv', "wt", encoding="utf-8") as f:
    f.write('booktitle,booklink\n')  
    for i in range(len(title)):
        f.write(title[i]+","+link[i]+'\n')
# Out:
# -- 도서 제목 --
# ['Do it! 점프 투 파이썬', '혼자 공부하는 파이썬', '혼자 공부하는 머신러닝+딥러닝', '두근두근 파이썬', '파이썬 for Beginner', '이것이 취업을 위한 코딩 테스트다 with 파이썬 ', '밑바닥부터 시작하는 딥러닝 ', '파이썬 증권 데이터 분석 ', '실전 시계열 분석', '핸즈온 머신러닝', '파이썬을 이용한 비트코인 자동매매', '파이썬 알고리즘 인터뷰', 'Do it! 파이썬 생활 프로그래밍', 'Do it! 점프 투 파이썬 + Do it! 파이썬 생활 프로그래밍', '파이썬 머신러닝 완벽 가이드', '어서와 파이썬은 처음이지!', '파이썬으로 배우는 컴퓨팅 사고', 'Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편', 'Do it! 점프 투 파이썬 + Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편 + Do it! 파이썬 생활 프로그래밍', 'Python 실습으로 기초부터']
# -- 도서 링크 URL --
# ['/Product/Goods/74419916?OzSrank=1', '/Product/Goods/74269975?OzSrank=2', '/Product/Goods/96024871?OzSrank=3', '/Product/Goods/35279965?OzSrank=4', '/Product/Goods/83849188?OzSrank=5', '/Product/Goods/91433923?OzSrank=6', '/Product/Goods/34970929?OzSrank=7', '/Product/Goods/90578506?OzSrank=8', '/Product/Goods/98576347?OzSrank=9', '/Product/Goods/89959711?OzSrank=10', '/Product/Goods/98135876?OzSrank=11', '/Product/Goods/91084402?OzSrank=12', '/Product/Goods/91437485?OzSrank=13', '/Product/Goods/91446225?OzSrank=14', '/Product/Goods/87044746?OzSrank=15', '/Product/Goods/30575427?OzSrank=16', '/Product/Goods/70749127?OzSrank=17', '/Product/Goods/91219874?OzSrank=18', '/Product/Goods/91446242?OzSrank=19', '/Product/Goods/98795965?OzSrank=20']

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108"
savename = "C:/Temp/forecast.xml"
req.urlretrieve(url, savename)

xml = open(savename, "r", encoding="utf-8").read()
soup = BeautifulSoup(xml, 'html.parser')

info = {}
for location in soup.find_all("location"):
    loc = location.find('city').string
    min_w = location.find_all('tmn')
    max_w = location.find_all('tmx')
    weather = [a.string+"~"+b.string for a, b in zip(min_w, max_w)]

    if not (loc in info):
        info[loc] = []
    for data in weather:
        info[loc].append(data)
print(info)

with open('C:/Temp/forecast.txt', "wt", encoding="utf-8") as f:
    for loc in sorted(info.keys()):
        f.write(str(loc)+'\n')
        for name in info[loc]:
            f.write('\t'+str(name)+'\n')

# %%
import json
import urllib.request

#User-Agent를 조작하는 경우 
hdr = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '+ 
        'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.80 Safari/537.36'}

req = urllib.request.Request('http://unico2013.dothome.co.kr/crawling/header.php', headers = hdr)
#req = urllib.request.Request('http://unico2013.dothome.co.kr/crawling/header.php')
data = urllib.request.urlopen(req).read()
print(data)
#page = data.decode('utf-8', 'ignore')
res_content = json.loads(data)

print(res_content["result"])
